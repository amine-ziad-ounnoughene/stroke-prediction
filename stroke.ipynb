# %% [markdown]
# ### setup's and imports

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### data laoding and preprocessing
# the stroke prediction data set

# %%
raw = pd.read_csv("/content/healthcare-dataset-stroke-data.csv")
from sklearn.model_selection import train_test_split
data = raw.drop(["id"], axis=1)
data["gender"] = data["gender"].astype("category").cat.codes
data["ever_married"] = data["ever_married"].astype("category").cat.codes
data["work_type"] = data["work_type"].astype("category").cat.codes
data["Residence_type"] = data["Residence_type"].astype("category").cat.codes
data["smoking_status"] = data["smoking_status"].astype("category").cat.codes
data = data.dropna(axis=0)
y = data.drop(["stroke"], axis=1)
x = data["stroke"]
train_labels = x.iloc[:3920]
test_labels = x.iloc[3920:]
train_x = y.iloc[:3920][:]
test_x = y.iloc[3920:][:]
# Out:
# {0: 'Female', 1: 'Male', 2: 'Other'}
# {0: 'No', 1: 'Yes'}
# {0: 'Govt_job', 1: 'Never_worked', 2: 'Private', 3: 'Self-employed', 4: 'children'}

# %% [markdown]
# ### Define a model

# %% [markdown]
# Start by building a simple sequential model:

# %%
# Define a simple sequential model
def create_model():
   model = keras.Sequential([
    keras.layers.Flatten(input_shape=(1,10)),  # input layer (1)
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(128, activation='softmax'),  # hidden layer (2)
    keras.layers.Dense(1, activation='sigmoid') # output layer (3)
  ])
   return model

# Create a basic model instance
model = create_model()
# compile the model 
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
# Display the model's architecture
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 10)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               1408
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 18,049
# Trainable params: 18,049
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### trainning the model

# %%
# Train the model 
model.fit(train_x, 
          train_labels,  
          epochs=10,
          validation_data=(test_x, test_labels),)  

# This may generate warnings related to saving the state of the optimizer.
# These warnings (and similar warnings throughout this notebook)
# are in place to discourage outdated usage, and can be ignored.
# Out:
# Epoch 1/10
# WARNING:tensorflow:Model was constructed with shape (None, 1, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1, 10), dtype=tf.float32, name='flatten_1_input'), name='flatten_1_input', description="created by layer 'flatten_1_input'"), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, 1, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1, 10), dtype=tf.float32, name='flatten_1_input'), name='flatten_1_input', description="created by layer 'flatten_1_input'"), but it was called on an input with incompatible shape (None, 10).
# 122/123 [============================>.] - ETA: 0s - loss: 0.5688 - accuracy: 0.9385WARNING:tensorflow:Model was constructed with shape (None, 1, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1, 10), dtype=tf.float32, name='flatten_1_input'), name='flatten_1_input', description="created by layer 'flatten_1_input'"), but it was called on an input with incompatible shape (None, 10).
# 123/123 [==============================] - 4s 4ms/step - loss: 0.5686 - accuracy: 0.9385 - val_loss: 0.4948 - val_accuracy: 1.0000
# Epoch 2/10
# 123/123 [==============================] - 0s 3ms/step - loss: 0.4823 - accuracy: 0.9467 - val_loss: 0.4126 - val_accuracy: 1.0000
# Epoch 3/10
# 123/123 [==============================] - 0s 3ms/step - loss: 0.4209 - accuracy: 0.9467 - val_loss: 0.3483 - val_accuracy: 1.0000
# Epoch 4/10
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3738 - accuracy: 0.9467 - val_loss: 0.2972 - val_accuracy: 1.0000
# Epoch 5/10
# 123/123 [==============================] - 0s 2ms/step - loss: 0.3373 - accuracy: 0.9467 - val_loss: 0.2562 - val_accuracy: 1.0000
# Epoch 6/10
# 123/123 [==============================] - 0s 3ms/step - loss: 0.3091 - accuracy: 0.9467 - val_loss: 0.2231 - val_accuracy: 1.0000
# Epoch 7/10
# 123/123 [==============================] - 0s 3ms/step - loss: 0.2873 - accuracy: 0.9467 - val_loss: 0.1963 - val_accuracy: 1.0000
# Epoch 8/10
# 123/123 [==============================] - 0s 3ms/step - loss: 0.2702 - accuracy: 0.9467 - val_loss: 0.1745 - val_accuracy: 1.0000
# Epoch 9/10
# 123/123 [==============================] - 0s 3ms/step - loss: 0.2568 - accuracy: 0.9467 - val_loss: 0.1563 - val_accuracy: 1.0000
# Epoch 10/10
# 123/123 [==============================] - 0s 3ms/step - loss: 0.2463 - accuracy: 0.9467 - val_loss: 0.1414 - val_accuracy: 1.0000

# %%
# Evaluate the model
loss, acc = model.evaluate(test_x, test_labels, verbose=2)
print("Untrained model, accuracy: {:5.2f}%".format(100 * acc))
# Out:
# 31/31 - 0s - loss: 0.1414 - accuracy: 1.0000
# Untrained model, accuracy: 100.00%

# %%
#test the model on new data
print(model.predict(test_x))
# Out:
# [[0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318698 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187046]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318698 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186976]
#  [0.1318697 ]
#  [0.1318698 ]
#  [0.13186973]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187423]
#  [0.1318697 ]
#  [0.13187046]
#  [0.13187078]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186996]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.13186973]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187014]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187009]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318698 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187017]
#  [0.1318697 ]
#  [0.13186984]
#  [0.1318697 ]
#  [0.13187003]
#  [0.13186973]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186982]
#  [0.13186996]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.13186997]
#  [0.1318697 ]
#  [0.1318699 ]
#  [0.13187101]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.13186976]
#  [0.13186976]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187975]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186976]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186982]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318699 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186987]
#  [0.13186997]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318698 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.13187115]
#  [0.13187057]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187039]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318698 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.13187069]
#  [0.13187003]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.13186976]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318698 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186976]
#  [0.13187031]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186997]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186982]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187039]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318698 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187   ]
#  [0.13186997]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187014]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318698 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186996]
#  [0.1318705 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186976]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186997]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186993]
#  [0.1318697 ]
#  [0.13186982]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186976]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186982]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.13186976]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186996]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186987]
#  [0.1318697 ]
#  [0.13186996]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.13186982]
#  [0.13186973]
#  [0.1318697 ]
#  [0.13186987]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187236]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.13186996]
#  [0.13186973]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187206]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.13186982]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187239]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.13186973]
#  [0.13186973]
#  [0.1318697 ]
#  [0.13186973]
#  [0.13186973]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187127]
#  [0.13187063]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.13186987]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187   ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187003]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186987]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318699 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186976]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186976]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318701 ]
#  [0.1318697 ]
#  [0.13186976]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186987]
#  [0.13186973]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187055]
#  [0.1318697 ]
#  [0.13186996]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186976]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187009]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186976]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.13186976]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318699 ]
#  [0.13186976]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.13187046]
#  [0.13187014]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318699 ]
#  [0.1318697 ]
#  [0.13186993]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187055]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186996]
#  [0.13186982]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187   ]
#  [0.1318698 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.13186997]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187046]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186996]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.13186984]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.13186973]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187023]
#  [0.1318697 ]
#  [0.13187025]
#  [0.1318698 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187014]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318698 ]
#  [0.13186973]
#  [0.13186976]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186976]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187   ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187017]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187003]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186987]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.13186973]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318698 ]
#  [0.13186973]
#  [0.1318698 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.13187364]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.13186973]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187248]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187   ]
#  [0.13187033]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187489]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13186973]
#  [0.13187023]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.13187009]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]
#  [0.1318697 ]]
